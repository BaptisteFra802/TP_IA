# %% [markdown]
# <a href="https://colab.research.google.com/github/BaptisteFra802/TP_IA/blob/main/Random_forest_Ethan_statWindow14_graph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Traitement des données
import pandas as pd
import numpy as np

# Création du modèle
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint

# Visualisation des réultats
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
import matplotlib.pyplot as plt

d=pd.read_csv("features_14.csv");
# Sépare le résultat (target) des infos renvoyées par le capteur
X = d.drop('Target', axis=1)
y = d['Target']

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#entrainement d'un modèle random forest sur le dataset d'entrainement
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

#on utilise le modèle sur le dataset de test, on stocke le résultat de ses prédictions dans y_pred
y_pred = rf.predict(X_test)

#on affiche la précision des prédictions par rapport aux class connus de l'ensemble de test
accuracy = accuracy_score(y_test, y_pred)
print("Précision : ", accuracy)

#Créé une série avec les caractéristiques par ordre d'importance dans le modèle
feature_importances = pd.Series(rf.feature_importances_, index=X_train.columns).sort_values(ascending=False)

# Affiche l'histogramme
plt.figure(figsize=(10, 6))
feature_importances.plot.bar();
plt.tight_layout() # Adjust layout to prevent overlapping labels
plt.show()
# Out:
# Précision :  0.9864253393665159

# %%
# prompt: using panda widden the above bar graph so the legend becomes readable

import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, ConfusionMatrixDisplay
from sklearn.model_selection import RandomizedSearchCV, train_test_split
from scipy.stats import randint
from sklearn.tree import export_graphviz
from IPython.display import Image
import graphviz
import matplotlib.pyplot as plt

# ... (your existing code)

# Affiche l'histogramme avec une légende plus large
plt.figure(figsize=(10, 6))  # Adjust figure size as needed
feature_importances.plot.bar();
plt.tight_layout() # Adjust layout to prevent overlapping labels
plt.show()
